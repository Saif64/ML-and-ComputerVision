# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
from google.colab import drive
drive.mount("content/")
# Out:
# Mounted at content/

# %%
img = cv2.imread("/content/content/MyDrive/Computer Vision with python/DATA/00-puppy.jpg")
type(img)
# Out:
# numpy.ndarray

# %%
#matplotlib --> RGB
#openCV --> BGR

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("/content/content/MyDrive/Computer Vision with python/DATA/00-puppy.jpg", cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray, cmap="gray")

# %%
new_img = cv2.resize(fix_img, (1000, 400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 3
h_ratio = 4

# %%
new_img2 = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)
plt.imshow(new_img2)

# %%
new_img2 = cv2.flip(fix_img, 0)
plt.imshow(new_img2)

# %%
cv2.imwrite("totally_new.jpg", fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(14, 12))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
